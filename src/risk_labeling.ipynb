# %% [markdown]
# # ⚠️ DEPRECATED PROTOTYPE
#
# This notebook is frozen historical reference only.
#
# Canonical Phase 2 implementation: [src/risk_model.py](src/risk_model.py)
# Canonical rebuild path: [src/pipeline.py](src/pipeline.py)
#
# Do not run or modify this notebook as part of the project workflow.
# It uses an older MinMaxScaler-based labeling idea and does not reflect the current pipeline contract.
#
# Current supported logic lives in `src/risk_model.py`, `src/predict.py`, and `src/validate_phase2.py`.
#
# This notebook is kept only for audit history.
